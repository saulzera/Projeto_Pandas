# %%
import pandas as pd

# %%
produtos = pd.read_csv('product_info.csv', sep=';')
compras = pd.read_csv('purchase.csv')
clientes = pd.read_csv('user_profile.csv', sep='|')

# %%
produtos.head(3)
# Out:
#   Product_ID  Product_Category_1  Product_Category_2  Product_Category_3
# 0  P00069042                   3                 NaN                 NaN
# 1  P00248942                   1                 6.0                14.0
# 2  P00087842                  12                 NaN                 NaN

# %%
compras.head(3)
# Out:
#    User_ID Product_ID  Purchase
# 0  1000001  P00069042      8370
# 1  1000001  P00248942     15200
# 2  1000001  P00087842      1422

# %%
clientes.head(3)
# Out:
#    User_ID Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0  1000001      F   0-17          10             A                          2
# 1  1000002      M    55+          16             C                         4+
# 2  1000003      M  26-35          15             A                          3
#
#    Marital_Status
# 0               0
# 1               0
# 2               0

# %%
df = clientes.merge(compras, on='User_ID', how='outer')
df
# Out:
#         User_ID Gender    Age  Occupation City_Category  \
# 0       1000001      F   0-17          10             A
# 1       1000001      F   0-17          10             A
# 2       1000001      F   0-17          10             A
# 3       1000001      F   0-17          10             A
# 4       1000001      F   0-17          10             A
# ...         ...    ...    ...         ...           ...
# 537572  1001529      M  18-25           4             C
# 537573  1001529      M  18-25           4             C
# 537574  1001529      M  18-25           4             C
# 537575  1001529      M  18-25           4             C
# 537576  1001529      M  18-25           4             C
#
#        Stay_In_Current_City_Years  Marital_Status Product_ID  Purchase
# 0                               2               0  P00069042      8370
# 1                               2               0  P00248942     15200
# 2                               2               0  P00087842      1422
# 3                               2               0  P00085442      1057
# 4                               2               0  P00085942     12842
# ...                           ...             ...        ...       ...
# 537572                         4+               1  P00148442     16245
# 537573                         4+               1  P00053942     15185
# 537574                         4+               1  P00182742     11975
# 537575                         4+               1  P00242742     11893
# 537576                         4+               1  P00063342     11641
#
# [537577 rows x 9 columns]

# %%
df = df.merge(produtos, on='Product_ID', how='outer')
df
# Out:
#         User_ID Gender    Age  Occupation City_Category  \
# 0       1000001      F   0-17          10             A
# 1       1000017      M  51-55           1             C
# 2       1000023      M  36-45           0             B
# 3       1000030      F  36-45           7             C
# 4       1000073      M  18-25           4             A
# ...         ...    ...    ...         ...           ...
# 537572  1005754      F  18-25           1             A
# 537573  1005948      M    55+          13             B
# 537574  1006001      F  26-35           7             A
# 537575  1002315      M    55+           7             C
# 537576  1003235      M  18-25           4             C
#
#        Stay_In_Current_City_Years  Marital_Status Product_ID  Purchase  \
# 0                               2               0  P00069042      8370
# 1                               0               0  P00069042     13591
# 2                               3               1  P00069042     11022
# 3                               3               0  P00069042      8036
# 4                              4+               0  P00069042     10885
# ...                           ...             ...        ...       ...
# 537572                          2               0  P00234942      7120
# 537573                          0               0  P00126342      9875
# 537574                          0               1  P00013442      2277
# 537575                         4+               1  P00063442      1866
# 537576                         4+               0  P00315242      7062
#
#         Product_Category_1  Product_Category_2  Product_Category_3
# 0                        3                 NaN                 NaN
# 1                        3                 NaN                 NaN
# 2                        3                 NaN                 NaN
# 3                        3                 NaN                 NaN
# 4                        3                 NaN                 NaN
# ...                    ...                 ...                 ...
# 537572                   5                 NaN                 NaN
# 537573                   8                 NaN                 NaN
# 537574                   8                 NaN                 NaN
# 537575                   5                 NaN                 NaN
# 537576                   5                 8.0                 NaN
#
# [537577 rows x 12 columns]

# %%
df.to_csv('DF')

# %%
df.head(50)
# Out:
#     User_ID Gender    Age  Occupation City_Category  \
# 0   1000001      F   0-17          10             A
# 49                          0               0  P00069042     13458
#
#     Product_Category_1  Product_Category_2  Product_Category_3
# 0                    3                 NaN                 NaN
# 1                    3                 NaN                 NaN
# 2                    3                 NaN                 NaN
# 3                    3                 NaN                 NaN
# 4                    3                 NaN                 NaN
# 5                    3                 NaN                 NaN
# 6                    3                 NaN                 NaN
# 7                    3                 NaN                 NaN
# 8                    3                 NaN                 NaN
# 9                    3                 NaN                 NaN
# 10                   3                 NaN                 NaN
# 11                   3                 NaN                 NaN
# 12                   3                 NaN                 NaN
# 13                   3                 NaN                 NaN
# 14                   3                 NaN                 NaN
# 15                   3                 NaN                 NaN
# 16                   3                 NaN                 NaN
# 17                   3                 NaN                 NaN
# 18                   3                 NaN                 NaN
# 19                   3                 NaN                 NaN
# 20                   3                 NaN                 NaN
# 21                   3                 NaN                 NaN
# 22                   3                 NaN                 NaN
# 23                   3                 NaN                 NaN
# 24                   3                 NaN                 NaN
# 25                   3                 NaN                 NaN
# 26                   3                 NaN                 NaN
# 27                   3                 NaN                 NaN
# 28                   3                 NaN                 NaN
# 29                   3                 NaN                 NaN
# 30                   3                 NaN                 NaN
# 31                   3                 NaN                 NaN
# 32                   3                 NaN                 NaN
# 33                   3                 NaN                 NaN
# 34                   3                 NaN                 NaN
# 35                   3                 NaN                 NaN
# 36                   3                 NaN                 NaN
# 37                   3                 NaN                 NaN
# 38                   3                 NaN                 NaN
# 39                   3                 NaN                 NaN
# 40                   3                 NaN                 NaN
# 41                   3                 NaN                 NaN
# 42                   3                 NaN                 NaN
# 43                   3                 NaN                 NaN
# 44                   3                 NaN                 NaN
# 45                   3                 NaN                 NaN
# 46                   3                 NaN                 NaN
# 47                   3                 NaN                 NaN
# 48                   3                 NaN                 NaN
# 49                   3                 NaN                 NaN

# %% [markdown]
# ## Questão 1
# Quantas observações e quantas colunas há no dataset completo (todas as bases juntas)? Responda no formato de uma tuple (n_observacoes, n_colunas).

# %%
df.shape
# Out:
# (537577, 12)

# %% [markdown]
# ## Questão 2
# Há quantas mulheres com idade entre 26 e 35 anos no dataset? Responda como um único escalar.

# %%
filtro = df[(df['Gender'] == 'F') & (df['Age'] == '26-35')]
filtro['User_ID'].nunique()
# Out:
# 545

# %% [markdown]
# ## Questão 3
# Quantos usuários únicos há no dataset? Responda como um único escalar.

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %% [markdown]
# ## Questão 4
# Qual porcentagem dos registros (percentual de linhas) possui ao menos um valor null (None, ǸaN etc)? Responda como um único escalar entre 0 e 1.

# %%
round((1 - (df.dropna().shape[0]) / df.shape[0]), 3)
# Out:
# 0.694

# %% [markdown]
# ## Questão 5
# Quantos valores null existem na variável (coluna) com o maior número de null? Responda como um único escalar.

# %%
df.isnull().sum().max()
# Out:
# 373299

# %% [markdown]
# ## Questão 6
# Qual o valor mais frequente (sem contar nulls) em Product_Category_3? Responda como um único escalar.

# %%
df['Product_Category_3'].value_counts().index[0]
# Out:
# 16.0

# %% [markdown]
# ## Questão 7
# Podemos afirmar que se uma observação é null em Product_Category_2 ela também o é em Product_Category_3? Responda com um bool (True, False).

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_ID                         0
# Purchase                           0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# dtype: int64

# %%
df[['Product_Category_3']]
# Out:
#         Product_Category_3
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 537572                 NaN
# 537573                 NaN
# 537574                 NaN
# 537575                 NaN
# 537576                 NaN
#
# [537577 rows x 1 columns]
